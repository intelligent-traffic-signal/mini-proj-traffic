# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../Sarakki_outputs/Test_weib/ncpu=1_15k/test_green10_3rdtime_run1.csv')

# %%
data_x = data.step_time
data_y = data.total_stopped

# %%
plt.plot(data_x, data_y)
plt.xlabel('Time Step')
plt.ylabel('Queue Length')
fig = plt.gcf()
fig.set_size_inches(10, 6)
fig.savefig('uniform', dpi=96)

# %%
plt.plot(data_x, data_y)
plt.xlabel('Time Step', fontsize = 40)
plt.ylabel('Queue Length (vehicles)', fontsize = 40)
plt.xticks(fontsize=40)
plt.yticks(fontsize=40)
fig = plt.gcf()
fig.set_size_inches(20, 12.25)
fig.savefig('uniform.eps', dpi=96, format = "eps")

# %%
ns = pd.read_csv('../Sarakki_outputs/Test_weib/ncpu=1_15k/test_nsload_green10_run1.csv')

# %%
ns_x = ns.step_time
ns_y = ns.total_stopped

# %%
plt.plot(ns_x, ns_y)
plt.xlabel('Time Step')
plt.ylabel('Queue Length')
fig = plt.gcf()
fig.set_size_inches(10, 6)
fig.savefig('nsload', dpi=96)

# %%
ew = pd.read_csv('../Sarakki_outputs/Test_weib/ncpu=1_15k/test_ewload_green10_run1.csv')

# %%
ew_x = ew.step_time
ew_y = ew.total_stopped

# %%
plt.plot(ew_x, ew_y)
plt.xlabel('Time Step')
plt.ylabel('Queue Length')
fig = plt.gcf()
fig.set_size_inches(10, 6)
fig.savefig('ewload', dpi=96)
